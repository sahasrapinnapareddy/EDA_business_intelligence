# %% [markdown]
# <a href="https://colab.research.google.com/github/sahasrapinnapareddy/EDA_business_intelligence/blob/main/deepdivedashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas numpy matplotlib seaborn plotly dash jupyter-dash
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 34.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 67.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
import plotly.graph_objects as go

from jupyter_dash import JupyterDash
from dash import dcc, html

# %%
data = {
    'Order Date': [
        '2024-01-01','2024-01-05','2024-01-10',
        '2024-02-01','2024-02-12','2024-03-01',
        '2024-03-15','2024-04-01','2024-04-10',
        '2024-05-01'
    ],

    'Category': [
        'Furniture','Technology','Office Supplies',
        'Technology','Furniture','Office Supplies',
        'Furniture','Technology','Office Supplies',
        'Furniture'
    ],

    'Region': [
        'East','West','South',
        'East','West','South',
        'Central','East','West',
        'Central'
    ],

    'Sales': [
        500,700,300,
        900,400,350,
        650,800,450,
        1000
    ],

    'Profit': [
        50,120,40,
        150,60,45,
        90,130,70,
        200
    ],

    'Order ID': [
        'CA-001','CA-002','CA-003',
        'CA-004','CA-005','CA-006',
        'CA-007','CA-008','CA-009',
        'CA-010'
    ]
}

df = pd.DataFrame(data)

df.head()
# Out:
#    Order Date         Category Region  Sales  Profit Order ID
# 0  2024-01-01        Furniture   East    500      50   CA-001
# 1  2024-01-05       Technology   West    700     120   CA-002
# 2  2024-01-10  Office Supplies  South    300      40   CA-003
# 3  2024-02-01       Technology   East    900     150   CA-004
# 4  2024-02-12        Furniture   West    400      60   CA-005

# %%
df.isnull().sum()
# Out:
# Order Date    0
# Category      0
# Region        0
# Sales         0
# Profit        0
# Order ID      0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Order Date', 'Category', 'Region', 'Sales', 'Profit', 'Order ID'], dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order Date  10 non-null     datetime64[ns]
#  1   Category    10 non-null     object
#  2   Region      10 non-null     object
#  3   Sales       10 non-null     int64
#  4   Profit      10 non-null     int64
#  5   Order ID    10 non-null     object
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 612.0+ bytes
#   Order Date         Category Region  Sales  Profit Order ID
# 0 2024-01-01        Furniture   East    500      50   CA-001
# 1 2024-01-05       Technology   West    700     120   CA-002
# 2 2024-01-10  Office Supplies  South    300      40   CA-003
# 3 2024-02-01       Technology   East    900     150   CA-004
# 4 2024-02-12        Furniture   West    400      60   CA-005

# %%
total_sales = df['Sales'].sum()
print("Total Sales:", total_sales)

total_profit = df['Profit'].sum()
print("Total Profit:", total_profit)

avg_order_value = df['Sales'].mean()
print("Average Order Value:", avg_order_value)

total_orders = df['Order ID'].nunique()
print("Total Orders:", total_orders)

total_orders = df['Order ID'].nunique()
print("Total Orders:", total_orders)
# Out:
# Total Sales: 6050
# Total Profit: 955
# Average Order Value: 605.0
# Total Orders: 10
# Total Orders: 10

# %%
category_sales = df.groupby('Category')['Sales'].sum().reset_index()

fig = px.bar(
    category_sales,
    x='Category',
    y='Sales',
    title='Sales by Category'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
region_profit = df.groupby('Region')['Profit'].sum().reset_index()

fig = px.pie(
    region_profit,
    names='Region',
    values='Profit',
    title='Profit by Region'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['Month'] = df['Order Date'].dt.to_period('M')

monthly_sales = df.groupby('Month')['Sales'].sum().reset_index()

monthly_sales['Month'] = monthly_sales['Month'].astype(str)

fig = px.line(
    monthly_sales,
    x='Month',
    y='Sales',
    title='Monthly Sales Trend'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

# Sales by Category
fig1 = px.bar(
    category_sales,
    x='Category',
    y='Sales',
    title='Sales by Category'
)

fig1.show()

# Profit by Region
fig2 = px.pie(
    region_profit,
    names='Region',
    values='Profit',
    title='Profit by Region'
)

fig2.show()

# Monthly Sales Trend
fig3 = px.line(
    monthly_sales,
    x='Month',
    y='Sales',
    title='Monthly Sales Trend'
)

fig3.show()

# KPI Output
print("========== KPI ANALYSIS ==========")

print("Total Sales:", round(total_sales,2))

print("Total Profit:", round(total_profit,2))

print("Average Order Value:", round(avg_order_value,2))

print("Total Orders:", total_orders)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
